# %%
import BollingerBacktester as bla

# %%
firstTest = bla.MeanRevBacktester("EUR_USD_Ask", 20, 1, '2017-01-21', "2020-12-31", 0.00015, 'D')

# %%
firstTest.optimize_parameters((20,30), (1,3))
# Out:
# ((22, 1), 1.189314)

# %%
fwd_test = bla.MeanRevBacktester("EUR_USD_Ask", 22, 1, '2021-01-01', "2021-12-31", 0.00015, 'D')

# %%
fwd_test.test_strategy()
# Out:
# (0.971001, 0.040422)

# %%
fwd_test.plot_results()
