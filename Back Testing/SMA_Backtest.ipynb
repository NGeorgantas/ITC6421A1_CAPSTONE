# %%
import SMABacktester as bla

# %%
firstTest = bla.SMABacktester("EUR_USD_Ask", 74, 250, '2017-01-21', "2020-12-31", 0.00015, '1h')

# %%
firstTest.optimize_parameters((15,75), (170,270))
# Out:
# ((20, 172), 1.145916)

# %%
fwd_test = bla.SMABacktester("EUR_USD_Ask", 20, 172, '2021-01-01', "2021-12-31", 0, '1h')

# %%
fwd_test.test_strategy()
# Out:
# (0.952692, 0.018537)

# %%
fwd_test.plot_results()
