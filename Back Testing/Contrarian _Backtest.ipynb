# %%
import ConBacktester as bla

# %%
firstTest = bla.ConBacktester("EUR_USD_Ask",'2017-01-21', "2020-12-31", 0.00015, '1h')

# %%
firstTest.optimize_parameter((1, 1000, 1))
# Out:
# (325, 1.065609)

# %%
fwd_test = bla.ConBacktester("EUR_USD_Ask", '2021-01-01', "2021-12-31", 0, '1h')

# %%
fwd_test.test_strategy(window=325)
# Out:
# (1.019291, 0.077932)

# %%
fwd_test.plot_results()
