# %%
import BacktestFORforest as forest
import MLBacktester as logreg

# %%
ml =  logreg.MLBacktester('c', "2017-01-02", "2021-12-30", 0)

# %%
for lags in range(1, 21):
    print(lags, ml.test_strategy(train_ratio = 0.8, lags = lags))
# Out:
# 1 (1.843943, 0.845899)
# 2 (2.122496, 1.124514)
# 3 (2.108669, 1.110582)
# 4 (2.121336, 1.123503)
# 5 (2.061776, 1.063988)
# 6 (2.080932, 1.083293)
# 7 (2.060901, 1.063464)
# 8 (2.037911, 1.040668)
# 9 (1.999327, 1.002057)
# 10 (1.991657, 0.994414)
# 11 (2.005787, 1.008755)
# 12 (2.016596, 1.019467)
# 13 (2.005977, 1.008663)
# 14 (1.996379, 0.999065)
# 15 (2.034557, 1.037173)
# 16 (1.994281, 0.997002)
# 17 (2.028525, 1.031167)
# 18 (1.975435, 0.978113)
# 19 (2.027677, 1.030266)
# 20 (1.979923, 0.982328)

# %%
ml.test_strategy(train_ratio = 0.8, lags = 5)
# Out:
# (1.681642, 0.757028)

# %%
ml.plot_results()

# %%
ml_2 =  forest.MLBacktester('c', "2017-01-02", "2021-12-30", 0)

# %%
for lags in range(1, 10):
    print(lags, ml_2.test_strategy(train_ratio = 0.8, lags = lags))

# %%
ml_2.test_strategy(train_ratio = 0.8, lags = 5)

# %%
ml_2.plot_results()
